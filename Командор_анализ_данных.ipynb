# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhamadsulton/-/blob/%D0%9C%D0%B5%D1%82%D0%BE%D0%B4%D1%8B-%D0%BE%D0%BF%D1%82%D0%B8%D0%BC%D0%B8%D0%B7%D0%B0%D1%86%D0%B8%D0%B8/%D0%9A%D0%BE%D0%BC%D0%B0%D0%BD%D0%B4%D0%BE%D1%80_%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ec7dae51-838b-43ac-952e-c22cab207d3c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ec7dae51-838b-43ac-952e-c22cab207d3c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 11.xlsx to 11.xlsx

# %%
sns.set(rc={'figure.figsize': (25, 5)})

# %%
data = pd.read_excel('11.xlsx')

# %%
data.head(20)
# Out:
#    Канал розничной торговли   Год  ...  Товарооборот  План товарооборот
# 0                     Г-1 К  2010  ...           0.0       0.000000e+00
# 1                     Г-1 К  2010  ...           0.0       0.000000e+00
# 2                     Г-1 К  2010  ...           0.0       0.000000e+00
# 3                     Г-1 К  2010  ...           0.0       0.000000e+00
# 4                     Г-1 К  2010  ...           0.0       0.000000e+00
# 5                     Г-1 К  2010  ...           0.0       0.000000e+00
# 6                     Г-1 К  2010  ...           0.0       0.000000e+00
# 7                     Г-1 К  2010  ...           0.0       0.000000e+00
# 8                     Г-1 К  2010  ...           0.0       0.000000e+00
# 9                     Г-1 К  2010  ...           0.0       0.000000e+00
# 10                    Г-1 К  2010  ...           0.0       0.000000e+00
# 11                    Г-1 К  2010  ...           0.0       0.000000e+00
# ...

# %%
data['Год'].unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015])

# %%
b = sns.barplot(x=data['Канал розничной торговли'],y=data['Кол-во чеков'])
b.figure.set_figwidth(30)
b.figure.set_figheight(10)
plt.show()

# %%
sns.barplot(data=data, x="Год", y="Товарооборот")
plt.show()

# %%
sns.lineplot(data=data, x="Год", y="Кол-во чеков")
plt.title('Кол-во чеков за 5 лет')
plt.show()

# %%
year10 = data[data['Год']==2010]

# %%
ax10 = sns.lineplot(data=year10, x="Месяц года", y="Кол-во чеков")

# %%
year11 = data[data['Год']==2011]

# %%
ax11 = sns.lineplot(data=year11, x="Месяц года", y="Кол-во чеков")

# %%
year12 = data[data['Год']==2012]

# %%
ax12 = sns.lineplot(data=year12, x="Месяц года", y="Кол-во чеков")

# %%
year13 = data[data['Год']==2013]

# %%
ax13 = sns.lineplot(data=year13, x="Месяц года", y="Кол-во чеков")

# %%
year14 = data[data['Год']==2014]

# %%
ax14 = sns.lineplot(data=year14, x="Месяц года", y="Кол-во чеков")

# %%
year15 = data[data['Год']==2015]

# %%
ax15 = sns.lineplot(data=year15, x="Месяц года", y="Кол-во чеков")

# %%
sns.barplot(x=year10['Канал розничной торговли'],y=year10['Кол-во чеков'])
plt.show()

# %%
sns.barplot(x=year11['Канал розничной торговли'],y=year11['Кол-во чеков'])
plt.show()

# %%
sns.barplot(x=year12['Канал розничной торговли'],y=year12['Кол-во чеков'])
plt.show()

# %%
b = sns.barplot(x=year13['Канал розничной торговли'],y=year13['Кол-во чеков'])
b.figure.set_figwidth(22)
b.figure.set_figheight(5)
plt.show()

# %%
c = sns.barplot(x=year14['Канал розничной торговли'],y=year14['Кол-во чеков'])
c.figure.set_figwidth(22)
c.figure.set_figheight(5)
plt.show()

# %%
d = sns.barplot(x=year15['Канал розничной торговли'],y=year15['Кол-во чеков'])
d.figure.set_figwidth(22)
d.figure.set_figheight(5)
plt.show()

# %%
sns.barplot(x=year13['Канал розничной торговли'],y=year13['Товарооборот'])
plt.show()

# %%
sns.barplot(x=year14['Канал розничной торговли'],y=year14['Товарооборот'])
plt.show()

# %%
sns.barplot(x=year15['Канал розничной торговли'],y=year15['Товарооборот'])
plt.show()

# %%
sns.barplot(x=year11['Канал розничной торговли'],y=year11['План товарооборот'])
plt.show()

# %%
sns.barplot(x=year12['Канал розничной торговли'],y=year12['План товарооборот'])
plt.show()

# %%
sns.barplot(x=year13['Канал розничной торговли'],y=year13['План товарооборот'])
plt.show()

# %%
sns.barplot(x=year14['Канал розничной торговли'],y=year14['План товарооборот'])
plt.show()

# %%
sns.barplot(x=year15['Канал розничной торговли'],y=year15['План товарооборот'])
plt.show()

# %%
data.corr()['План товарооборот']
# Out:
# Год                  0.202383
# Месяц года           0.028925
# Кол-во чеков         0.794175
# Товарооборот         0.739563
# План товарооборот    1.000000
# Name: План товарооборот, dtype: float64

# %%
train = data[data['Год'] != 2010]

# %%
df = train[['Кол-во чеков','План товарооборот']]

# %%
df.head()
# Out:
#     Кол-во чеков  План товарооборот
# 12  35220.383693       1.743158e+07
# 13  36158.513189       1.780830e+07
# 14  42239.328537       2.080798e+07
# 15  40680.095923       1.915201e+07
# 16  41036.690647       2.104633e+07

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X = df.drop(['План товарооборот'],axis=1)
y = df['План товарооборот']

# %%
X = scaler.fit_transform(X)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear = LinearRegression()

# %%
regressia = linear.fit(X,y)

# %%
pred = regressia.predict(X)

# %%
from sklearn.metrics import mean_squared_error,r2_score
import numpy as np

# %%
rmse = (np.sqrt(mean_squared_error(y, pred)))
r2 = r2_score(y, pred)

# %%
print(rmse)
print(r2)
# Out:
# 2100455.427523999
# 0.7926103716270881

# %%
pred
# Out:
# array([16776719.11314633, 17292296.54266218, 20634192.47319218, ...,
#         3530122.11911823,  3385676.09080806,  -804181.28693691])

# %%
fig, dx = plt.subplots()
dx.scatter(X, y, s=10)
dx.plot(X, pred, color='r')
dx.set_xlabel("Количество чеков")
dx.set_ylabel("План товарооборота")
dx.set_title("Линейная регрессия")
plt.show()

# %%
X_poly = poly.fit_transform(X)

# %%
pol_reg = LinearRegression()

# %%
pol_reg.fit(X_poly, y)
y_pred = pol_reg.predict(X_poly)

rmse1 = np.sqrt(mean_squared_error(y,y_pred))
r21 = r2_score(y,y_pred)
print(rmse1)
print(r21)
# Out:
# 1829087.681598015
# 0.8427360632611454

# %%
import operator

# %%
fig, cx = plt.subplots()
cx.scatter(X, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(X,y_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
cx.plot(X, y_pred, color='m')
cx.set_xlabel("Количество чеков")
cx.set_ylabel("План товарооборота")
cx.set_title("полиномиальная регрессия с полиномом степени 2")
plt.show()
